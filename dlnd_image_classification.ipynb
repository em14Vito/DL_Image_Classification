# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 4
sample_id = 2
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 4:
# Samples: 10000
# Label Counts: {0: 1003, 1: 963, 2: 1041, 3: 976, 4: 1004, 5: 1021, 6: 1004, 7: 981, 8: 1024, 9: 983}
# First 20 Labels: [0, 6, 0, 2, 7, 2, 1, 2, 4, 1, 5, 6, 6, 3, 1, 3, 5, 5, 8, 1]
#
# Example of Image 2:
# Image - Min Value: 2 Max Value: 204
# Image - Shape: (32, 32, 3)
# Label - Label Id: 0 Name: airplane

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Impement Function
     
    x = np.array(x)
    x_min = x.min()
    x_max = x.max()    
    x = (x - x_min) / (x_max - x_min)

    return x
   


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    
    #eye(5)[0,1,2,3,4]这个解释，相乘是怎么做到的？
  
 #     sample = [0,1,2,3,4]
#     print("Before")
#     print(sample)
#     print("After")
#     print(np.eye(5)[sample])
    ans = np.eye(10)[x]
    return ans


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    new_shape = [None,image_shape[0],image_shape[1],image_shape[2]]   
    x = tf.placeholder(tf.float32, shape= new_shape,name = "x")    
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function  
    new_shape = [None,n_classes]   
    x = tf.placeholder(tf.float32, shape= new_shape,name ="y")    
    return x


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32,name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    #x_tensor.shape.as_list()[3]不懂
    weight = tf.Variable( tf.truncated_normal((conv_ksize[0],conv_ksize[1],
                                               x_tensor.shape.as_list()[3],conv_num_outputs),dtype=tf.float32))
           
    conv = tf.nn.conv2d(x_tensor,weight,strides=[1,conv_strides[0],conv_strides[1],1], padding='SAME')
    
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    conv = tf.nn.bias_add(conv,bias)
    
    conv = tf.nn.relu(conv)
    
    output = tf.nn.max_pool( conv,
                           ksize =[1, pool_ksize[0], pool_ksize[1], 1] ,
                           strides=[1,pool_strides[0],pool_strides[1],1],
                           padding='SAME')
    
    return output
    
#     Add a nonlinear activation to the convolution.
#     Apply Max Pooling using pool_ksize and pool_strides.
#     We recommend you use same padding, but you're welcome to use any padding.
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    dim = x_tensor.get_shape().as_list()  
    product = 1
    for i in dim[1:4]:    
        product = i*product
        
    result = tf.reshape(x_tensor,[-1,product])
    return result
    
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    inputs = x_tensor.get_shape().as_list()[1]
    weights = tf.Variable(tf.truncated_normal([inputs, num_outputs], stddev=0.05, mean=0.0))
    bias = tf.Variable(tf.zeros(num_outputs))
    logits = tf.add(tf.matmul(x_tensor, weights), bias)
    return tf.nn.relu(logits)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function    
    
    inputs = x_tensor.get_shape().as_list()[1]
    weights = tf.Variable(tf.truncated_normal([inputs, num_outputs], stddev=0.05, mean=0.0))
    bias = tf.Variable(tf.zeros(num_outputs))
    logits = tf.add(tf.matmul(x_tensor, weights), bias)   
    
    return logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
#     conv_num_outputs = [32,64]
#     conv_ksize = [(3, 3),(3,3)]
#     conv_strides = [(1, 1),(1,1)]
#     pool_ksize = [(1,1),(2, 2)]
#     pool_strides = [(1,1),(2,2)]
#     num_outputs = 10
#     layer2 = conv2d_maxpool(x, conv_num_outputs[1], conv_ksize[1], conv_strides[1], pool_ksize[1], pool_strides[0])
#     layer2 = conv2d_maxpool(layer1,  conv_num_outputs[1], conv_ksize[1], conv_strides[1], pool_ksize[1], pool_strides[1])
#     layer1 = conv2d_maxpool(layer1, 64, conv_ksize, conv_strides, pool_ksize, pool_strides)
#     layer1 = conv2d_maxpool(layer1, 128, conv_ksize, conv_strides, pool_ksize, pool_strides)
#     layer2 = tf.nn.dropout(layer1, keep_prob)
    
    conv_num_outputs = 64
    conv_ksize = (3, 3)
    conv_strides = (1, 1)
    pool_ksize = (2, 2)
    pool_strides = (2, 2)
    num_outputs=10
       
    layer2 = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)

    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    layer3 =  flatten(layer2)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    layer4 = fully_conn(layer3,512)
    #layer4 = tf.nn.dropout(layer4, keep_prob)
    layer4 = fully_conn(layer4,256)
    

    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(layer4,num_outputs)
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: keep_probability})   

    
    pass
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    loss = session.run(cost, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: 1.0})
    
    
    valid_acc = session.run(accuracy, feed_dict={
                x: valid_features,
                y: valid_labels,
                keep_prob: 1.0})
    
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
                loss,
                valid_acc))
    
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 64
keep_probability = 0.2

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.0280 Validation Accuracy: 0.346800
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.7422 Validation Accuracy: 0.400800
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.4827 Validation Accuracy: 0.458800
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.3388 Validation Accuracy: 0.456000
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.0985 Validation Accuracy: 0.496400
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.1392 Validation Accuracy: 0.520200
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.0305 Validation Accuracy: 0.526000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     0.8883 Validation Accuracy: 0.522800
# Epoch  9, CIFAR-10 Batch 1:  Loss:     0.7582 Validation Accuracy: 0.525600
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.6145 Validation Accuracy: 0.543200
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.5575 Validation Accuracy: 0.511400
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.4397 Validation Accuracy: 0.535000
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.3876 Validation Accuracy: 0.536000
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.3405 Validation Accuracy: 0.550000
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.3229 Validation Accuracy: 0.518000
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.2531 Validation Accuracy: 0.537000
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.2258 Validation Accuracy: 0.536800
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.1892 Validation Accuracy: 0.529600
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.2403 Validation Accuracy: 0.529800
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.2017 Validation Accuracy: 0.528000
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.1277 Validation Accuracy: 0.527000
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.1595 Validation Accuracy: 0.507800
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.0414 Validation Accuracy: 0.510400
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.0329 Validation Accuracy: 0.542400
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.0226 Validation Accuracy: 0.533600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.0203 Validation Accuracy: 0.539400
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.0581 Validation Accuracy: 0.524600
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.0120 Validation Accuracy: 0.540200
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.0128 Validation Accuracy: 0.549600
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.0079 Validation Accuracy: 0.547200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.0043 Validation Accuracy: 0.557600
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.0119 Validation Accuracy: 0.538200
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.0040 Validation Accuracy: 0.551800
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0071 Validation Accuracy: 0.538000
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.0049 Validation Accuracy: 0.547400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0043 Validation Accuracy: 0.547200
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0132 Validation Accuracy: 0.528800
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0042 Validation Accuracy: 0.537000
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0033 Validation Accuracy: 0.538000
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0051 Validation Accuracy: 0.546200
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0103 Validation Accuracy: 0.541400
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0076 Validation Accuracy: 0.546000
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0113 Validation Accuracy: 0.548200
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0044 Validation Accuracy: 0.550000
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0039 Validation Accuracy: 0.546400
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0015 Validation Accuracy: 0.545400
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0018 Validation Accuracy: 0.547000
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0015 Validation Accuracy: 0.552000
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0027 Validation Accuracy: 0.517600
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0054 Validation Accuracy: 0.542800
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0077 Validation Accuracy: 0.527000
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0121 Validation Accuracy: 0.530000
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0066 Validation Accuracy: 0.544000
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0053 Validation Accuracy: 0.534800
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0026 Validation Accuracy: 0.543000
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0029 Validation Accuracy: 0.548200
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0035 Validation Accuracy: 0.545000
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0020 Validation Accuracy: 0.531600
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0079 Validation Accuracy: 0.540000
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0038 Validation Accuracy: 0.542200
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.0068 Validation Accuracy: 0.538000
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0013 Validation Accuracy: 0.533600
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.0068 Validation Accuracy: 0.531600
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.539400
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0022 Validation Accuracy: 0.534000
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.536200
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.0034 Validation Accuracy: 0.539000
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0016 Validation Accuracy: 0.532000
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0034 Validation Accuracy: 0.528000
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0038 Validation Accuracy: 0.545800
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0010 Validation Accuracy: 0.540200
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0029 Validation Accuracy: 0.547800
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.545400
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.549800
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.554600
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.554200
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.554400
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.554200
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.555000
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.555800
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.554600
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.555800
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.555600
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.555800
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.556000
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.556000
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.555800
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.556000
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.557000
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.556600
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.556200
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.556400
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.556000
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.556200
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.557000
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.557600
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.557200
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.557400
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.557800
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.558200

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     1.9933 Validation Accuracy: 0.365400
# Epoch  1, CIFAR-10 Batch 2:  Loss:     1.2746 Validation Accuracy: 0.461800
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.2920 Validation Accuracy: 0.519200
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.2563 Validation Accuracy: 0.520800
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.2155 Validation Accuracy: 0.552400
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.4224 Validation Accuracy: 0.546400
# Epoch  2, CIFAR-10 Batch 2:  Loss:     0.9659 Validation Accuracy: 0.547200
# Epoch  2, CIFAR-10 Batch 3:  Loss:     0.8742 Validation Accuracy: 0.585400
# Epoch  2, CIFAR-10 Batch 4:  Loss:     0.9457 Validation Accuracy: 0.594400
# Epoch  2, CIFAR-10 Batch 5:  Loss:     0.9738 Validation Accuracy: 0.591600
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.1086 Validation Accuracy: 0.608600
# Epoch  3, CIFAR-10 Batch 2:  Loss:     0.7100 Validation Accuracy: 0.581400
# Epoch  3, CIFAR-10 Batch 3:  Loss:     0.6089 Validation Accuracy: 0.616800
# Epoch  3, CIFAR-10 Batch 4:  Loss:     0.7594 Validation Accuracy: 0.629400
# Epoch  3, CIFAR-10 Batch 5:  Loss:     0.7237 Validation Accuracy: 0.610800
# Epoch  4, CIFAR-10 Batch 1:  Loss:     0.9288 Validation Accuracy: 0.637000
# Epoch  4, CIFAR-10 Batch 2:  Loss:     0.5827 Validation Accuracy: 0.613800
# Epoch  4, CIFAR-10 Batch 3:  Loss:     0.4601 Validation Accuracy: 0.628600
# Epoch  4, CIFAR-10 Batch 4:  Loss:     0.5962 Validation Accuracy: 0.635800
# Epoch  4, CIFAR-10 Batch 5:  Loss:     0.5373 Validation Accuracy: 0.615800
# Epoch  5, CIFAR-10 Batch 1:  Loss:     0.7199 Validation Accuracy: 0.633200
# Epoch  5, CIFAR-10 Batch 2:  Loss:     0.4738 Validation Accuracy: 0.626200
# Epoch  5, CIFAR-10 Batch 3:  Loss:     0.3300 Validation Accuracy: 0.638600
# Epoch  5, CIFAR-10 Batch 4:  Loss:     0.4258 Validation Accuracy: 0.647000
# Epoch  5, CIFAR-10 Batch 5:  Loss:     0.4148 Validation Accuracy: 0.642200
# Epoch  6, CIFAR-10 Batch 1:  Loss:     0.5859 Validation Accuracy: 0.626000
# Epoch  6, CIFAR-10 Batch 2:  Loss:     0.4044 Validation Accuracy: 0.601800
# Epoch  6, CIFAR-10 Batch 3:  Loss:     0.2730 Validation Accuracy: 0.641200
# Epoch  6, CIFAR-10 Batch 4:  Loss:     0.3949 Validation Accuracy: 0.619200
# Epoch  6, CIFAR-10 Batch 5:  Loss:     0.3518 Validation Accuracy: 0.645400
# Epoch  7, CIFAR-10 Batch 1:  Loss:     0.5022 Validation Accuracy: 0.629200
# Epoch  7, CIFAR-10 Batch 2:  Loss:     0.3187 Validation Accuracy: 0.622800
# Epoch  7, CIFAR-10 Batch 3:  Loss:     0.2281 Validation Accuracy: 0.630400
# Epoch  7, CIFAR-10 Batch 4:  Loss:     0.3123 Validation Accuracy: 0.625200
# Epoch  7, CIFAR-10 Batch 5:  Loss:     0.2463 Validation Accuracy: 0.641000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     0.5023 Validation Accuracy: 0.628200
# Epoch  8, CIFAR-10 Batch 2:  Loss:     0.2785 Validation Accuracy: 0.628400
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.1466 Validation Accuracy: 0.596800
# Epoch  8, CIFAR-10 Batch 4:  Loss:     0.2259 Validation Accuracy: 0.632000
# Epoch  8, CIFAR-10 Batch 5:  Loss:     0.2281 Validation Accuracy: 0.627200
# Epoch  9, CIFAR-10 Batch 1:  Loss:     0.3623 Validation Accuracy: 0.632600
# Epoch  9, CIFAR-10 Batch 2:  Loss:     0.2634 Validation Accuracy: 0.589800
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.1584 Validation Accuracy: 0.590200
# Epoch  9, CIFAR-10 Batch 4:  Loss:     0.3224 Validation Accuracy: 0.588600
# Epoch  9, CIFAR-10 Batch 5:  Loss:     0.1918 Validation Accuracy: 0.626400
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.2913 Validation Accuracy: 0.608600
# Epoch 10, CIFAR-10 Batch 2:  Loss:     0.1568 Validation Accuracy: 0.606400
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.0765 Validation Accuracy: 0.601600
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.3011 Validation Accuracy: 0.598200
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.1742 Validation Accuracy: 0.629400
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.2352 Validation Accuracy: 0.626400
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.0534 Validation Accuracy: 0.612200
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.1206 Validation Accuracy: 0.608600
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.1255 Validation Accuracy: 0.613600
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.1225 Validation Accuracy: 0.631400
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.1641 Validation Accuracy: 0.613200
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.1163 Validation Accuracy: 0.628800
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.0710 Validation Accuracy: 0.628800
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.0677 Validation Accuracy: 0.612400
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.1248 Validation Accuracy: 0.597200
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.1508 Validation Accuracy: 0.628800
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.0301 Validation Accuracy: 0.631600
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.0710 Validation Accuracy: 0.618600
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.1020 Validation Accuracy: 0.608400
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.1918 Validation Accuracy: 0.601000
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.1321 Validation Accuracy: 0.626400
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.0688 Validation Accuracy: 0.619000
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.0735 Validation Accuracy: 0.607200
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.0370 Validation Accuracy: 0.616400
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.0893 Validation Accuracy: 0.605800
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.1332 Validation Accuracy: 0.635800
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.0637 Validation Accuracy: 0.615400
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.0367 Validation Accuracy: 0.600800
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.0872 Validation Accuracy: 0.614600
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.0329 Validation Accuracy: 0.619200
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.0787 Validation Accuracy: 0.634800
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.0377 Validation Accuracy: 0.618400
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.0194 Validation Accuracy: 0.626200
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.0306 Validation Accuracy: 0.616200
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.0301 Validation Accuracy: 0.594600
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.0528 Validation Accuracy: 0.634000
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.0101 Validation Accuracy: 0.619200
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.0413 Validation Accuracy: 0.637600
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.0122 Validation Accuracy: 0.629600
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.0279 Validation Accuracy: 0.615000
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.0500 Validation Accuracy: 0.620000
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.0143 Validation Accuracy: 0.602000
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.0217 Validation Accuracy: 0.626800
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.0240 Validation Accuracy: 0.621800
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.0062 Validation Accuracy: 0.625400
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.0200 Validation Accuracy: 0.613200
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.0125 Validation Accuracy: 0.603400
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.0067 Validation Accuracy: 0.626800
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.0226 Validation Accuracy: 0.629200
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.0866 Validation Accuracy: 0.619200
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.0260 Validation Accuracy: 0.612000
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.0074 Validation Accuracy: 0.592800
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.0250 Validation Accuracy: 0.625400
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.0073 Validation Accuracy: 0.628000
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.0106 Validation Accuracy: 0.624400
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.0069 Validation Accuracy: 0.630600
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.0184 Validation Accuracy: 0.616200
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.0114 Validation Accuracy: 0.625800
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.0218 Validation Accuracy: 0.617800
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.0212 Validation Accuracy: 0.611800
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.0047 Validation Accuracy: 0.624400
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.0071 Validation Accuracy: 0.603400
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.0145 Validation Accuracy: 0.611200
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.0434 Validation Accuracy: 0.598400
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.0067 Validation Accuracy: 0.620200
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.0191 Validation Accuracy: 0.630400
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.0062 Validation Accuracy: 0.619800
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.0082 Validation Accuracy: 0.623400
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.0125 Validation Accuracy: 0.619400
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.0241 Validation Accuracy: 0.614200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.0139 Validation Accuracy: 0.630400
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.0174 Validation Accuracy: 0.623400
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.0046 Validation Accuracy: 0.610400
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.0065 Validation Accuracy: 0.610400
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.0018 Validation Accuracy: 0.614600
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.0037 Validation Accuracy: 0.632800
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.0140 Validation Accuracy: 0.622800
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.0012 Validation Accuracy: 0.617800
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.0062 Validation Accuracy: 0.617400
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.0096 Validation Accuracy: 0.623800
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.0132 Validation Accuracy: 0.629000
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.0016 Validation Accuracy: 0.618800
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.0025 Validation Accuracy: 0.605800
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.0080 Validation Accuracy: 0.616800
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.0096 Validation Accuracy: 0.623600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.0069 Validation Accuracy: 0.620200
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.0014 Validation Accuracy: 0.611800
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.0021 Validation Accuracy: 0.613000
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.0030 Validation Accuracy: 0.623200
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.0186 Validation Accuracy: 0.622200
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.0098 Validation Accuracy: 0.618000
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.0060 Validation Accuracy: 0.620800
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.0009 Validation Accuracy: 0.607200
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.0081 Validation Accuracy: 0.615800
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.0073 Validation Accuracy: 0.625600
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.0051 Validation Accuracy: 0.623800
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.0027 Validation Accuracy: 0.628400
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.0019 Validation Accuracy: 0.614600
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.0047 Validation Accuracy: 0.617200
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.0034 Validation Accuracy: 0.621600
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.0057 Validation Accuracy: 0.611000
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.0016 Validation Accuracy: 0.621800
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.0013 Validation Accuracy: 0.624400
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.0026 Validation Accuracy: 0.626400
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.0020 Validation Accuracy: 0.632600
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.0128 Validation Accuracy: 0.627400
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.0016 Validation Accuracy: 0.622400
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.0847 Validation Accuracy: 0.616800
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.0068 Validation Accuracy: 0.611000
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.0080 Validation Accuracy: 0.629800
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.0122 Validation Accuracy: 0.625400
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.0013 Validation Accuracy: 0.609000
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.0039 Validation Accuracy: 0.610200
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.0013 Validation Accuracy: 0.624000
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.0027 Validation Accuracy: 0.623600
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.0059 Validation Accuracy: 0.624000
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.0004 Validation Accuracy: 0.622200
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.0014 Validation Accuracy: 0.631400
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.0012 Validation Accuracy: 0.627200
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.0058 Validation Accuracy: 0.626200
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0015 Validation Accuracy: 0.620000
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.0019 Validation Accuracy: 0.620000
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.0006 Validation Accuracy: 0.628600
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.0027 Validation Accuracy: 0.624200
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.0025 Validation Accuracy: 0.630400
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.0085 Validation Accuracy: 0.623200
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.0009 Validation Accuracy: 0.618600
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.0023 Validation Accuracy: 0.623200
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.0031 Validation Accuracy: 0.635200
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.0050 Validation Accuracy: 0.632200
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0036 Validation Accuracy: 0.624400
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.0036 Validation Accuracy: 0.625800
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.0072 Validation Accuracy: 0.623400
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.0073 Validation Accuracy: 0.623000
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.0007 Validation Accuracy: 0.627000
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0024 Validation Accuracy: 0.627800
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.0019 Validation Accuracy: 0.621200
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.0004 Validation Accuracy: 0.627600
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.0080 Validation Accuracy: 0.624800
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.0040 Validation Accuracy: 0.632600
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.625800
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.0023 Validation Accuracy: 0.629000
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.0022 Validation Accuracy: 0.631000
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.0046 Validation Accuracy: 0.629400
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.0005 Validation Accuracy: 0.622200
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0030 Validation Accuracy: 0.621600
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.0005 Validation Accuracy: 0.630200
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.0019 Validation Accuracy: 0.628000
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.622400
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.0007 Validation Accuracy: 0.624800
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0030 Validation Accuracy: 0.624600
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.0133 Validation Accuracy: 0.618400
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.0018 Validation Accuracy: 0.628800
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.0064 Validation Accuracy: 0.628800
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.0012 Validation Accuracy: 0.627400
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0014 Validation Accuracy: 0.618000
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.0029 Validation Accuracy: 0.623200
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.0005 Validation Accuracy: 0.635200
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.0015 Validation Accuracy: 0.614600
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.0023 Validation Accuracy: 0.635600
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0036 Validation Accuracy: 0.618600
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.0016 Validation Accuracy: 0.634600
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.0055 Validation Accuracy: 0.630400
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.0012 Validation Accuracy: 0.620000
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.0036 Validation Accuracy: 0.632000
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0038 Validation Accuracy: 0.615600
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.0028 Validation Accuracy: 0.617800
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.0079 Validation Accuracy: 0.621800
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.0023 Validation Accuracy: 0.615800
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.0096 Validation Accuracy: 0.617600
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0052 Validation Accuracy: 0.624200
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.0032 Validation Accuracy: 0.622200
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.620800
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.0012 Validation Accuracy: 0.605800
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.0009 Validation Accuracy: 0.625800
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0033 Validation Accuracy: 0.619200
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.0072 Validation Accuracy: 0.624600
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.0018 Validation Accuracy: 0.635200
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.0014 Validation Accuracy: 0.630400
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.0013 Validation Accuracy: 0.629800
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0041 Validation Accuracy: 0.627800
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.0038 Validation Accuracy: 0.622600
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.0031 Validation Accuracy: 0.624600
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.0020 Validation Accuracy: 0.626200
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.0023 Validation Accuracy: 0.635600
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy: 0.615400
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.0029 Validation Accuracy: 0.628800
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.0013 Validation Accuracy: 0.612800
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.0029 Validation Accuracy: 0.614000
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.0015 Validation Accuracy: 0.635800
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0020 Validation Accuracy: 0.629400
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.0010 Validation Accuracy: 0.620400
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.0015 Validation Accuracy: 0.628400
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.619000
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.0003 Validation Accuracy: 0.626200
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0041 Validation Accuracy: 0.629800
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.624800
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.0028 Validation Accuracy: 0.623200
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.624800
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.0030 Validation Accuracy: 0.625200
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0029 Validation Accuracy: 0.629400
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.0022 Validation Accuracy: 0.619400
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.0009 Validation Accuracy: 0.624400
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.0037 Validation Accuracy: 0.620200
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.0018 Validation Accuracy: 0.616000
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0027 Validation Accuracy: 0.626600
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.0011 Validation Accuracy: 0.626600
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.0033 Validation Accuracy: 0.625600
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.0068 Validation Accuracy: 0.618000
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.0017 Validation Accuracy: 0.627000
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0051 Validation Accuracy: 0.626000
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.0017 Validation Accuracy: 0.628400
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.0005 Validation Accuracy: 0.622600
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.0005 Validation Accuracy: 0.625600
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.0065 Validation Accuracy: 0.629400
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy: 0.619000
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.0022 Validation Accuracy: 0.624800
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.630200
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.0014 Validation Accuracy: 0.624200
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.0006 Validation Accuracy: 0.627600
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0037 Validation Accuracy: 0.628400
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.621200
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.623200
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.0268 Validation Accuracy: 0.617800
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.0006 Validation Accuracy: 0.631600
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0016 Validation Accuracy: 0.615400
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.627200
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.0008 Validation Accuracy: 0.628000
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy: 0.620000
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.0147 Validation Accuracy: 0.626600
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0098 Validation Accuracy: 0.622200
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.0011 Validation Accuracy: 0.626800
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.0004 Validation Accuracy: 0.624000
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.0016 Validation Accuracy: 0.619200
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.0011 Validation Accuracy: 0.617000
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.633800
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.0014 Validation Accuracy: 0.629800
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.621800
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.0016 Validation Accuracy: 0.627800
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.0010 Validation Accuracy: 0.624600
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0007 Validation Accuracy: 0.620400
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.626200
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.0031 Validation Accuracy: 0.623200
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.622600
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.0022 Validation Accuracy: 0.627600
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0106 Validation Accuracy: 0.619800
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.0010 Validation Accuracy: 0.625000
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.0047 Validation Accuracy: 0.618400
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.0008 Validation Accuracy: 0.613800
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy: 0.626200
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0007 Validation Accuracy: 0.616400
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.0005 Validation Accuracy: 0.625600
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.0015 Validation Accuracy: 0.633400
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy: 0.621600
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.0006 Validation Accuracy: 0.624600
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy: 0.623200
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.0006 Validation Accuracy: 0.619400
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.0009 Validation Accuracy: 0.623400
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.624600
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.0027 Validation Accuracy: 0.630800
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0014 Validation Accuracy: 0.635000
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.0006 Validation Accuracy: 0.620000
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.0008 Validation Accuracy: 0.622200
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.0009 Validation Accuracy: 0.622000
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.0018 Validation Accuracy: 0.622200
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.619600
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.618200
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.0010 Validation Accuracy: 0.621200
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.0013 Validation Accuracy: 0.618000
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.0074 Validation Accuracy: 0.626600
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0014 Validation Accuracy: 0.627000
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.623200
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.0065 Validation Accuracy: 0.629600
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.0019 Validation Accuracy: 0.621800
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.0005 Validation Accuracy: 0.620400
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0022 Validation Accuracy: 0.625000
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.0038 Validation Accuracy: 0.621400
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.0101 Validation Accuracy: 0.612400
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.0007 Validation Accuracy: 0.612000
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.626400
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.620000
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.0014 Validation Accuracy: 0.616200
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.0005 Validation Accuracy: 0.624800
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.0214 Validation Accuracy: 0.614200
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.0064 Validation Accuracy: 0.618600
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.0108 Validation Accuracy: 0.625200
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.609200
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.0014 Validation Accuracy: 0.623200
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.0015 Validation Accuracy: 0.620800
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.0012 Validation Accuracy: 0.625800
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0029 Validation Accuracy: 0.626800
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.0015 Validation Accuracy: 0.621400
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.0017 Validation Accuracy: 0.630200
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.0036 Validation Accuracy: 0.618000
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.0013 Validation Accuracy: 0.630000
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy: 0.617400
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.0018 Validation Accuracy: 0.625600
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.0007 Validation Accuracy: 0.623800
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy: 0.625000
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.0032 Validation Accuracy: 0.626400
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.616200
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.0020 Validation Accuracy: 0.622000
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.0015 Validation Accuracy: 0.620400
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.625200
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.622000
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.617200
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.627200
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.0033 Validation Accuracy: 0.624600
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.0010 Validation Accuracy: 0.615400
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.0010 Validation Accuracy: 0.629400
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.626000
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.623000
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.0005 Validation Accuracy: 0.615800
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.0021 Validation Accuracy: 0.614400
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.0035 Validation Accuracy: 0.624400
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.630800
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.620000
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.623800
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.0019 Validation Accuracy: 0.616000
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.625800
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0019 Validation Accuracy: 0.618800
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.0009 Validation Accuracy: 0.620000
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.0011 Validation Accuracy: 0.626600
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.0010 Validation Accuracy: 0.625600
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.0008 Validation Accuracy: 0.625600
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0019 Validation Accuracy: 0.620400
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.627800
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.0020 Validation Accuracy: 0.629000
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.0011 Validation Accuracy: 0.627600
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.0024 Validation Accuracy: 0.626600
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.621600
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.0032 Validation Accuracy: 0.623000
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.0011 Validation Accuracy: 0.620000
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.0005 Validation Accuracy: 0.623400
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.0023 Validation Accuracy: 0.622200
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.621000
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.0004 Validation Accuracy: 0.620600
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.0020 Validation Accuracy: 0.627400
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.0012 Validation Accuracy: 0.621800
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.0042 Validation Accuracy: 0.628000
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.630400
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.631400
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.628600
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.0018 Validation Accuracy: 0.622000
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.626400
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.636400
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.629400
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.0013 Validation Accuracy: 0.625600
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.614000
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.0091 Validation Accuracy: 0.621800
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy: 0.617800
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.627400
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.0008 Validation Accuracy: 0.627800
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy: 0.621600
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.0006 Validation Accuracy: 0.625400
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0030 Validation Accuracy: 0.628600
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.624200
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.624800
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.623800
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.0003 Validation Accuracy: 0.626800
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0012 Validation Accuracy: 0.629800
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.0047 Validation Accuracy: 0.626600
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.0014 Validation Accuracy: 0.616600
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.626400
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.0033 Validation Accuracy: 0.617800
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.618800
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.0004 Validation Accuracy: 0.620600
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.621000
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.630800
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.0006 Validation Accuracy: 0.619600
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.626200
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.622400
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.0005 Validation Accuracy: 0.625000
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.613200
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.618200
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.622000
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.630000
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.0003 Validation Accuracy: 0.616200
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.614600
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy: 0.618000
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0017 Validation Accuracy: 0.622600
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.0015 Validation Accuracy: 0.622600
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.0020 Validation Accuracy: 0.616800
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.614400
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.0003 Validation Accuracy: 0.616400
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0007 Validation Accuracy: 0.624800
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.0008 Validation Accuracy: 0.627200
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.0011 Validation Accuracy: 0.619400
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.615200
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.0024 Validation Accuracy: 0.615400
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.623200
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.622000
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.629800
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.0015 Validation Accuracy: 0.620800
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.618400
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.629200
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.0009 Validation Accuracy: 0.621200
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.0010 Validation Accuracy: 0.622800
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.619400
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.0010 Validation Accuracy: 0.603400
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.621000
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.614800
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.617800
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.621600
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.0016 Validation Accuracy: 0.619400
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0019 Validation Accuracy: 0.622400
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.629800
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.0003 Validation Accuracy: 0.628400
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.0030 Validation Accuracy: 0.617800
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.0026 Validation Accuracy: 0.617400
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0033 Validation Accuracy: 0.617800
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.622800
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.0018 Validation Accuracy: 0.617200
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.623000
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy: 0.617400
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0316 Validation Accuracy: 0.611400
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.0005 Validation Accuracy: 0.619600
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.622600
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.0026 Validation Accuracy: 0.620200
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.0025 Validation Accuracy: 0.623400
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.629000
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.618000
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.0010 Validation Accuracy: 0.616400
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.0005 Validation Accuracy: 0.620600
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.620800
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.625400
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.0010 Validation Accuracy: 0.620200
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.0013 Validation Accuracy: 0.621200
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.628400
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.618800
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.612600
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.0004 Validation Accuracy: 0.624600
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.617000
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.621800
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.618200
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.624600
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.619800
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.623000
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.627200
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy: 0.619200
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.625000
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.629000
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.609400
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.613200
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.0006 Validation Accuracy: 0.629000
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0007 Validation Accuracy: 0.619000
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.620800
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.622800
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.625200
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.627200
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.625400
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.0004 Validation Accuracy: 0.619000
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.0003 Validation Accuracy: 0.622000
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.0007 Validation Accuracy: 0.627000
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.625800

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6225119426751592

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
